# %%
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %%
title = "Data Science"
location = 'Toronto'

# %%
list_url = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Data%2BScience&location=Toronto&geoId=100761630&distance=25&f_TPR=&f_E=1&start=0"
response = requests.get(list_url)

list_data = response.text
list_soup = BeautifulSoup(list_data, 'html.parser')
page_jobs = list_soup.find_all('li')

# %%
id_list = []
for job in page_jobs:
    base_card_div = job.find('div', {'class': 'base-card'})
    job_id = base_card_div.get('data-entity-urn').split(':')[3]
    id_list.append(job_id)
    print(job_id)
# Out:
# 4157845565
# 4158928976
# 4151697992
# 4119528432
# 4152020457
# 4119525609
# 4148824726
# 4142865462
# 4137836889
# 4152269714

# %%
job_list = []
for job_id in id_list:
    job_post = {}
    job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
    job_response = requests.get(job_url)
    print(job_response.status_code)
    job_soup = BeautifulSoup(job_response.text, 'html.parser')
    try:
    job_post['company_name'] = job_soup.find('a', {'class': 'topcard__org-name-link topcard__flavor--black-link'}).text.strip()
    job_post['time_posted'] = job_soup.find('span', {'class': 'posted-time-ago__text posted-time-ago__text--new topcard__flavor--metadata'}).text.strip()
    job_post['time_posted'] = job_soup.find('span', {'class': 'num-applicants__caption'}).text.strip()
    
    job_list.append(job_post)
# Out:
# 200
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 9
#       7 job_soup = BeautifulSoup(job_response.text, 'html.parser')
#       8 job_post['company_name'] = job_soup.find('a', {'class': 'topcard__org-name-link topcard__flavor--black-link'}).text.strip()
# ----> 9 job_post['time_posted'] = job_soup.find('span', {'class': 'posted-time-ago__text posted-time-ago__text--new topcard__flavor--metadata'}).text.strip()
#      10 job_post['time_posted'] = job_soup.find('span', {'class': 'num-applicants__caption'}).text.strip()
#      12 job_list.append(job_post)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
job_list
# Out:
# [{'company_name': 'Medcan'},
#  {'company_name': 'Diaryz'},
#  {'company_name': 'Stripe'},
#  {'company_name': 'Vosyn'},
#  {'company_name': 'Klick'},
#  {'company_name': 'Vosyn'},
#  {'company_name': 'City of Toronto'},
#  {'company_name': 'Compugen Inc'},
#  {'company_name': 'BMW Group Financial Services Canada'},
#  {'company_name': 'Keurig Dr Pepper Canada'}]

# %%
job_response.text
# Out:
# '\n\n    \n<!---->    \n    \n\n    \n    <section class="top-card-layout container-lined overflow-hidden babybear:rounded-[0px]">\n        \n      \n\n      <div class="top-card-layout__card relative p-2 papabear:p-details-container-padding">\n            \n        \n      <a href="https://ca.linkedin.com/company/diaryz?trk=public_jobs_topcard_logo" target="_self" data-tracking-control-name="public_jobs_topcard_logo" data-tracking-will-navigate>\n        \n          \n      <img class="artdeco-entity-image artdeco-entity-image--square-5\n          " data-delayed-url="https://media.licdn.com/dms/image/v2/C560BAQF48y7tVS0WuA/company-logo_100_100/company-logo_100_100/0/1658083200763?e=2147483647&amp;v=beta&amp;t=sxUYbIDuhsLbtvS3xpG5PDiHHMht05hWCSi4AxeJiV0" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/aajlclc14rr2scznz5qm2rj9u" alt="Diaryz">\n  \n        \n      </a>\n  \n      \n\n          <div class="top-card-layout__entity-info-container flex flex-wrap papabear:flex-nowrap">\n            <div class="top-card-layout__entity-info flex-grow flex-shrink-0 basis-0 babybear:flex-none babybear:w-full babybear:flex-none babybear:w-full">\n                  \n          <a href="https://ca.linkedin.com/jobs/view/junior-front-end-developer-at-diaryz-4158928976?trk=public_jobs_topcard-title" data-tracking-control-name="public_jobs_topcard-title" class="topcard__link" data-tracking-will-navigate>\n            <h2 class="top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title">Junior Front End Developer</h2>\n          </a>\n      \n<!---->\n<!---->\n                <h4 class="top-card-layout__second-subline font-sans text-sm leading-open text-color-text-low-emphasis mt-0.5">\n                  \n        <div class="topcard__flavor-row">\n          <span class="topcard__flavor">\n              <a class="topcard__org-name-link topcard__flavor--black-link" data-tracking-control-name="public_jobs_topcard-org-name" data-tracking-will-navigate href="https://ca.linkedin.com/company/diaryz?trk=public_jobs_topcard-org-name" rel="noopener" target="_blank">\n                Diaryz\n              </a>\n          </span>\n            <span class="topcard__flavor topcard__flavor--bullet">\n              Toronto, Ontario, Canada\n            </span>\n        </div>\n        <div class="topcard__flavor-row">\n          \n        <span class="posted-time-ago__text posted-time-ago__text--new topcard__flavor--metadata">\n          \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      8 hours ago\n  \n        </span>\n  \n          \n    \n    \n    \n\n        <figure class="num-applicants__figure topcard__flavor--metadata topcard__flavor--bullet">\n          <span class="num-applicants__icon num-applicants__icon--notify-pebble lazy-load"></span>\n          <figcaption class="num-applicants__caption">\n            Over 200 applicants\n          </figcaption>\n        </figure>\n  \n        </div>\n          \n    \n\n    \n      \n    \n      <a href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fsearch%2Fresults%2Fpeople%2F%3FfacetCurrentCompany%3D18657974&amp;emailAddress=&amp;fromSignIn=&amp;trk=public_jobs_see-who-was-hired_people-search-link_face-pile-cta" target="_self" data-tracking-control-name="full-link" data-tracking-will-navigate class="face-pile flex !no-underline see-who-was-hired">\n        \n      <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">\n          \n      <img class="inline-block relative\n          rounded-[50%]\n          w-4 h-4\n           face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/aemitl4w713xg3xvy9bcrecox"  ...
